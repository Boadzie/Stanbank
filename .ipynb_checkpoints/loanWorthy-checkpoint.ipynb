# %%
import numpy as np
import pandas as pd
from sklearn import tree

input_file = "Loan.csv"
df = pd.read_csv(input_file, header = 0)

# %%
df.head()
# Out:
#    Age  Experience  Income  Address  Family  CCAvg  Education  Mortgage  \
# 0   25           1      49    91107       4    1.6          1         0
# 1   45          19      34    90089       3    1.5          1         0
# 2   39          15      11    94720       1    1.0          1         0
# 3   35           9     100    94112       1    2.7          2         0
# 4   35           8      45    91330       4    1.0          2         0
#
#    PersonalLoan  SecuritiesAccount  CDAccount  Online  CreditCard  Customerid  \
# 0             0                  1          0       0           0           1
# 1             0                  1          0       0           0           2
# 2             1                  0          0       0           0           3
# 3             0                  0          0       0           0           4
# 4             1                  0          1       0           1           5
#
#    Gender  Loan_worthiness
# 0       0                0
# ...

# %%
target = df['Loan_worthiness']

# %%
df2 = pd.DataFrame(df)

# %%
df['Age']= df['Age'].map((target))
df['Experience']= df['Experience'].map((target))
df['Income']= df['Income'].map((target))
df['Family']= df['Family'].map((target))
df['CCAvg']= df['CCAvg'].map((target))
df['Education']= df['Education'].map((target))
df['Mortgage']= df['Mortgage'].map((target))
df['PersonalLoan']= df['PersonalLoan'].map((target))
df['SecuritiesAccount']= df['SecuritiesAccount'].map((target))
df['CDAccount']= df['CDAccount'].map((target))
df['Online']= df['Online'].map((target))
df['CreditCard']= df['CreditCard'].map((target))
df['Gender']= df['Gender'].map((target))

# %%
df2.head()
# Out:
#    Age  Experience  Income  Address  Family  CCAvg  Education  Mortgage  \
# 0  NaN         1.0     NaN    91107       1    NaN          1       0.0
# 1  NaN         NaN     NaN    90089       0    NaN          1       0.0
# 2  NaN         NaN     NaN    94720       1    1.0          1       0.0
# 3  NaN         NaN     NaN    94112       1    NaN          1       0.0
# 4  NaN         1.0     NaN    91330       1    1.0          1       0.0
#
#    PersonalLoan  SecuritiesAccount  CDAccount  Online  CreditCard  Customerid  \
# 0             0                  1          0       0           0           1
# 1             0                  1          0       0           0           2
# 2             1                  0          0       0           0           3
# 3             0                  0          0       0           0           4
# 4             1                  0          1       0           1           5
#
#    Gender  Loan_worthiness
# 0       0                0
# ...
